# %%
from speciesot import Experiment

# %%
### Example usage of package

experiment_spec_path = "/n/holylabs/mooney_lab/Lab/joshprice/speciesOT/experiment_config_example_090326.yaml"
experiment = Experiment(experiment_spec_path)

experiment.setup()
experiment.train()
experiment.predict()
experiment.evaluate()
