# %%
from speciesot import Experiment, DummyEvaluation

# %%
### Example usage of package

experiment_spec_path = "specs/e24_tiny_identity.yaml"
experiment = Experiment(experiment_spec_path)

experiment.setup()
experiment.train()
experiment.predict()
print(experiment.evaluate())
assert isinstance(experiment.evaluations[0], DummyEvaluation)
